# %%
import pandas as pd
import os
import glob
from sklearn.metrics import confusion_matrix

# %%
file_path = r"V:\dunwei\MACE\dataset\TabPFN_result\non_drug_8feature_NA2_merge_divided_window/"
save_path = file_path + r"combine/"

# %%
if not os.path.exists(save_path):
    os.makedirs(save_path)
    print(f'create directory: {save_path}')
else:
    print(f'{save_path} already exists')
# Out:
# V:\dunwei\MACE\dataset\TabPFN_result\non_drug_8feature_NA2_merge_divided_window/combine/ already exists

# %%
dataset = "test"
mode = 2
"""
mode = 1 ---> combine label
mode = 2 ---> combine probability
"""
if mode == 1:
    file_name = f"y_{dataset}_label"
elif mode == 2:
    file_name = f"yhat_{dataset}_probability"
else:
    raise ValueError("mode error")

# %%
total_file = os.path.join(file_path, f"y_test_label_*.csv")
file_list = sorted(glob.glob(total_file))

# %%
data_list = []
for i in range(int(len(file_list)/89)):
    print(f'load file num: {i + 1}')
    for ii in range(89):  # number of folds
        print(f'load fold num: {ii + 1}')
        data = pd.read_csv(file_path + f"{file_name}_{i + 1}_{ii + 1}.csv")
        data_list.append(data)

data_df = pd.concat(data_list, axis=0)
data_df['SortKey'] = data_df.iloc[:, 0].str.extract(r'(\d+)').astype(int)  # 提取數字部分，轉換為數值型
data_df_sorted = data_df.sort_values(by='SortKey').reset_index(drop=True)  # 按數字部分排序
data_df_sorted = data_df_sorted.drop(columns=['SortKey'])  # 刪除輔助列
data_df_sorted.to_csv(save_path + f"{file_name}_combine.csv", index=False)

# 統計每個編號的樣本數
sample_counts = data_df_sorted.iloc[:, 0].value_counts().reset_index()
# 重新命名欄位名稱
sample_counts.columns = ['ID', 'Sample_num']
# # 按照 ID 排序（確保 MACE001、MACE002 順序正確）
sample_counts['SortKey'] = sample_counts['ID'].str.extract(r'(\d+)').astype(int)
sample_counts = sample_counts.sort_values(by='SortKey').drop(columns=['SortKey']).reset_index(drop=True)
sample_counts.to_csv(save_path + f"sample_num_{dataset}.csv", index=False)

print(f'\n===========   SAVE INFO   ===========')
print(f"all of files and results saved in {save_path}\n")
# Out:
# load file num: 1
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 2
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 3
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 4
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 5
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 6
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 7
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
# load file num: 8
# load fold num: 1
# load fold num: 2
# load fold num: 3
# load fold num: 4
# load fold num: 5
# load fold num: 6
# load fold num: 7
# load fold num: 8
# load fold num: 9
# load fold num: 10
# load fold num: 11
# load fold num: 12
# load fold num: 13
# load fold num: 14
# load fold num: 15
# load fold num: 16
# load fold num: 17
# load fold num: 18
# load fold num: 19
# load fold num: 20
# load fold num: 21
# load fold num: 22
# load fold num: 23
# load fold num: 24
# load fold num: 25
# load fold num: 26
# load fold num: 27
# load fold num: 28
# load fold num: 29
# load fold num: 30
# load fold num: 31
# load fold num: 32
# load fold num: 33
# load fold num: 34
# load fold num: 35
# load fold num: 36
# load fold num: 37
# load fold num: 38
# load fold num: 39
# load fold num: 40
# load fold num: 41
# load fold num: 42
# load fold num: 43
# load fold num: 44
# load fold num: 45
# load fold num: 46
# load fold num: 47
# load fold num: 48
# load fold num: 49
# load fold num: 50
# load fold num: 51
# load fold num: 52
# load fold num: 53
# load fold num: 54
# load fold num: 55
# load fold num: 56
# load fold num: 57
# load fold num: 58
# load fold num: 59
# load fold num: 60
# load fold num: 61
# load fold num: 62
# load fold num: 63
# load fold num: 64
# load fold num: 65
# load fold num: 66
# load fold num: 67
# load fold num: 68
# load fold num: 69
# load fold num: 70
# load fold num: 71
# load fold num: 72
# load fold num: 73
# load fold num: 74
# load fold num: 75
# load fold num: 76
# load fold num: 77
# load fold num: 78
# load fold num: 79
# load fold num: 80
# load fold num: 81
# load fold num: 82
# load fold num: 83
# load fold num: 84
# load fold num: 85
# load fold num: 86
# load fold num: 87
# load fold num: 88
# load fold num: 89
#
# ===========   SAVE INFO   ===========
# all of files and results saved in V:\dunwei\MACE\dataset\TabPFN_result\non_drug_8feature_NA2_merge_divided_window/combine/
