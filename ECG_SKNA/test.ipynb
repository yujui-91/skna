# %%
import numpy as np

file_path = r"D:\M143020071\raw_data_result\iSKNA_signal\ch1\sr10000_500_1000_15s_ECG_signal_1000pts\mace_zscore\284502332153.npy"
data = np.load(file_path)

print("資料維度 (Shape):", data.shape)

print("資料內容:")
print(data)
# Out:
# 資料維度 (Shape): (3001,)
# 資料內容:
# [1.         0.79093758 0.94896909 ... 1.45834428 1.1890588  0.86135016]

# %%
from scipy.io import loadmat
